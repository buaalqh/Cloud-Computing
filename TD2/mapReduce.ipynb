# %% [markdown]
# <h6><center>Cloud Computing  et informatique distribuée</center></h6>
#
# <h1>
# <hr style=" border:none; height:3px;">
# <center>Lab Assignment 2: Introduction to MapReduce</center>
# <hr style=" border:none; height:3px;">
# </h1>
#
#
# # First Part : Introduction
#
# MapReduce is a programming model useful in for big data processing and allows running a parallel and distributed  algorithm on a cluster.
#
# A MapReduce algorithm is composed of:
# <ul>
#     <li> a map function, which performs a first set of operations on the input data and, usually, produces a set of key-value pairs as output  </li>
#     <li> a reduce function, which performs an operation on the data coming as output from the map function grouped on the basis of the key.</li>
# </ul>
#
# The MapReduce algorithm can be run on a framework (i.e. Hadoop). In this case the framework will handle the process of
# running the algorithm on the distributed architecture running the various tasks in parallel, managing all communications and data transfers between the various parts of the system, and providing for redundancy and fault tolerance. The map function and the reduce function will then become independent procedures running in multiple instances in parallel.
#
# The map and the reduce procedures can be seen then as two main functions: map() et reduce().
#
# ### Map
#
# In general the map() function is seen as a function that:
# <ul>
#     <li> takes as input one (or a series) key/value pair(s);  </li>
#     <li> processes each key/value pair according to the procedure it implements;</li>
#     <li> generates as output zero or more key/value pairs.</li>
# </ul>
#
# It is important to notice that:
# <ul>
#     <li> if the input data is composed by single values each sigle value can be seen as a key/value pair having an empty  value;  </li>
#     <li> the types of the input key/value pair and the output key/value pair(s) can be (and often are) different from each other;</li>
#     <li> output key/value pair can have a dummy key;</li>
#     <li> also the output key/value pair can have an empty value.</li>
# </ul>
#
# In the example shown in the slides the application is counting the number of occurrences of each word in the provided file. The map function would take as input a single line. This single line can be seen as a key/value pair having as key the whole line and as value an empty value. The function will break the line into words and output a key/value pair for each word. The key will be the string representing the word and the value will be the integer 1.
#
#
# ### Shuffle
# Between the map() and reduce() functions, the data are shuffled in order to move together data sharing the same key.
# Data will be then processed by the reduce function.
# When you run a MapReduce procedure on a framework the shuffle operation is fully and transparently handled by the framework.
#
#
#
#
# ### Reduce
# The reduce() function applies a procedure on all the pairs that share the same key.
#
# It is important to notice that:
# <ul>
#     <li> the reduce function produces zero or more outputs for each group of key-value pairs  </li>
#     <li> the type of the output can be different from the input and can be also one or a set of key/value pair(s);</li>
#     <li> even in this case the key/value pair can have an empty value.</li>
# </ul>
#
#
#
# In the word count example, the reduce function takes the input values, sums them, and generates a single output containing a set of key/value pairs having as key the value of each word and as value the final sum.
#
# # Example: Counting global number of elements
#
#
# As first step you have as input some integers that are stored in multiple lists.
#
# Suppose that you have as input these lists:
#
#
# a = [1, 2, 3]
# b = [4, 5, 6, 7]
# c = [8, 9, 1, 2, 3]
#
# A possible solution can run two steps:
#
# <ul>
#     <li> a map function that gives as output the number of elements in each list; </li>
# (_,3)
# (_,4)
# (_,5) with the dummy key "_".
#     <li> a reduce function that adds the partial results coming from the map (using the dummy key) and returns 12</li>
# </ul>
#
#
# In this first series of exercises we will learn how to write programs according to the MapReduce paradigm.

# %% [markdown]
# # Exercise 1 : Counting even and odd numbers
#
#
# <p align="justify">
# <font size="3">
# Suppose that we have a file that contains lines of integers. We must find how many even and how many odd numbers we have in the file.
#
# We can implement a MapReduce procedure.
#
#
# <ol>
#     <li> Define a map function that for each odd number produces a key-value pair (o,1) and for each even number produces (e,1).</li>
#     <li> Define a reduce function that adds the values. </li>
#   </ol>
# </font>
# </p>
#
#
#
# ## Step 1 - map()
#
#
# <p align="justify">
# <font size="3">
# We can encode each line of the document as a list of integers.
# The map function will then take as input this list of integers and we are going to define a Python function that generates, given a list of integer, a pair (o,1) for each odd number and a pair (e,1) for each even number.
#
# Suppose that the file contains the following lines:
#
# 1 2 3 3
#
# 3 4 4
#
# 5 6 7
#
# 9 8 7 4
#
# In this example for the first line we will have
#
# (o,1), (e,1), (o,1), (o,1)
#
# For the second line:
#
# (o,1), (e,1), (e,1)
#
# etc.
#
# In order to read the line you can use the function array_reader that takes as input a file name and reads the file:
#
# </font>
# </p>

# %%
def array_reader(filename):
    numbers = [line.strip() for line in open(filename)]
    newnumbers = []
    for ln in numbers :
        newnumbers.append([int(i) for i in ln.split(" ")])
    print(newnumbers)
    return (newnumbers)

# %%
#Provide here few comment lines that describe your map function

def map_odd_even_sol(array):
    pairs = []
    #to complete with your code
    for line in array :
        buffer = []
        for e in line :
            if int(e) % 2 == 0 :
                buffer.append(('e',1))
            else:
                buffer.append(('o',1))
        pairs.append(buffer)
        
    return (pairs)

array_numbers = array_reader("numbers.txt")
res = map_odd_even_sol(array_numbers)
print(res)
# Out:
# [[1, 2, 3, 3], [3, 4, 4], [5, 6, 7], [9, 8, 7, 4]]
# [[('o', 1), ('e', 1), ('o', 1), ('o', 1)], [('o', 1), ('e', 1), ('e', 1)], [('o', 1), ('e', 1), ('o', 1)], [('o', 1), ('e', 1), ('o', 1), ('e', 1)]]

# %% [markdown]
# How can we improve our function?

# %%
#Provide here few comment lines that describe your map function

def map_odd_even_simple_sol(array):
    res = []
    #to complete with your code
    for line in array:
        res.append([('o',1) if (num % 2 ==1) else('e',1) for num in line])
    return res
        
array_numbers = array_reader("numbers.txt")
res = map_odd_even_simple_sol(array_numbers)
print(res)
# Out:
# [[1, 2, 3, 3], [3, 4, 4], [5, 6, 7], [9, 8, 7, 4]]
# [[('o', 1), ('e', 1), ('o', 1), ('o', 1)], [('o', 1), ('e', 1), ('e', 1)], [('o', 1), ('e', 1), ('o', 1)], [('o', 1), ('e', 1), ('o', 1), ('e', 1)]]

# %% [markdown]
# ## Step 2 - shuffle()
#
# <p align="justify">
# <font size="3">
# Here we are going to define a functions that groups the pairs according to the values of the key.
#
# We have a list of list of pairs:
#
# [[(o, 1), (e, 1), (o,1), (e,1)], [(o, 1),(e,1),(e,1)], [(o, 1), (e, 1), (o,1)], [(o, 1), (e, 1), (o,1), (e,1)]]
#
# and we have to create two lists of pairs:
#
# [[(o, 1), (o, 1), (o, 1), (o, 1), (o, 1), (o, 1), (o, 1)], [(e, 1), (e, 1), (e, 1), (e, 1), (e, 1), (e, 1), (e, 1)]]
#
# </font>
# </p>

# %%
#Provide here few comment lines that describe your shuffle function

def shuffle_odd_even_sol(pairs):
    odd = []
    even = []

    for line in pairs :
        for (k,v) in line :
            if k=='o':
                odd.append((k,v))
            else:
                even.append((k,v))
                
    result = [odd,even] 
    return (result)

res = shuffle_odd_even_sol(map_odd_even_sol(array_numbers))
print(res)
# Out:
# [[('o', 1), ('o', 1), ('o', 1), ('o', 1), ('o', 1), ('o', 1), ('o', 1), ('o', 1)], [('e', 1), ('e', 1), ('e', 1), ('e', 1), ('e', 1), ('e', 1)]]

# %% [markdown]
# ## Step 3 - reduce()
#
# <p align="justify">
# <font size="3">
# Here we are going to define the function that it is going to produce the final result.
# We are going to run the reduce function for each key (here for each different group, then twice).
# </font>
# </p>

# %%
#Provide here few comment lines that describe your reduce function

def reduce_sol(pairs):
    #to complete with your code
    result = []
    for line in pairs :
        result.append((line[0][0],len(line)))
        
    return result

#Provide here the code that calls your reduce function according to your implementation

res = reduce_sol(shuffle_odd_even_sol(map_odd_even_sol(array_numbers)))
print(res)
# Out:
# [('o', 8), ('e', 6)]

# %% [markdown]
# # Exercise 2: A simple program
#
# <p align="justify">
# <font size="3">
# Suppose now that we want to count the number of occurrences of each number as we did for the file containing words.
#
#
# 1 2 3 4
#
# 3 4  4
#
# 5 6 7
#
# 9 8 7 4
# </font>
# </p>
#
#
#
#
# <p align="justify">
# <font size="3">
# For our file we will have as result:
#
# [[1, 1], [2, 1], [3, 2], [4, 4], [5, 1], [6, 1], [7, 2], [8, 1], [9, 1]]
#
# </font>
# </p>
#
#
#
#
#
# <p align="justify">
# <font size="3">
# We can go again step by step:
#
#
#
# <ol>
# <li> Define a function that produces pairs for each line </li>
#     [(1, 1), (2, 1), (3, 1), (4, 1), (3, 1), (4, 1), (4,1), (5, 1), (6, 1), (7, 1), (9, 1), ...]
#
# <li> define a function that shuffles and groups in general according to the key </li>
#     [[[1, 1]], [[2, 1]], [[3, 1], [3, 1]], [[4, 1], [4, 1]], ...]
#
# <li> define a function reduce that sums up the results </li>
#     [[1, 1], [2, 1], [3, 2], [4, 4], [5, 1], [6, 1], [7, 2], [8, 1], [9, 1]]
#
# </ol>
# We try to reuse the functions previously defined.
# </font>
# </p>
#
#
#
# ## Step 1 - map()
# <p align="justify">
# <font size="3">
# We are going to define a Python function that generates, given a list of list of integers a pair (n,1) for each element
# of the list.
# </font>
# </p>
#
#
#
#
# 1 2 3 4
#
# 3 4  4
#
# 5 6 7
#
# 9 8 7 4
#
#
# <p align="justify">
# <font size="3">
# For the first line we will have:
# </font>
# </p>
#
# (1,1), (2,1), (3,1), (4,1)
#
#
#
# <p align="justify">
# <font size="3">
# For the second:
# </font>
# </p>
#
# (3,1), (4,1), (4,1)
#
# etc.

# %%
#Provide here few comment lines that describe your map function
array_numbers = array_reader("numbers.txt")

def map_num_counter_sol(array):
    numPairs = []
    # to complete
    for line in array:
        for e in line:
            numPairs.append((e,1))
    
    return (numPairs)

res=map_num_counter_sol(array_numbers)
print(res)


#res = []
#for line in array_numbers :
#  res += map_num_counter_sol(line)
#print(res)
# Out:
# [[1, 2, 3, 3], [3, 4, 4], [5, 6, 7], [9, 8, 7, 4]]
# [(1, 1), (2, 1), (3, 1), (3, 1), (3, 1), (4, 1), (4, 1), (5, 1), (6, 1), (7, 1), (9, 1), (8, 1), (7, 1), (4, 1)]

# %% [markdown]
# ## Step 2 - shuffle()
#
# <p align="justify">
# <font size="3">
# In this function we are going to group according to the integer in the key and we can store the result in a dictionary.
# </font>
# </p>

# %%
from collections import defaultdict

#Provide here few comment lines that describe your shuffle function


def shuffle_pairs_sol(input) :
     #to complete with your code
    
    result = defaultdict(list)
    for (k,v) in input :
        result[k].append(1)#字典的用法

    return (result)
        

res = shuffle_pairs_sol(map_num_counter_sol(array_numbers))
print(res)
# Out:
# defaultdict(<class 'list'>, {1: [1], 2: [1], 3: [1, 1, 1], 4: [1, 1, 1], 5: [1], 6: [1], 7: [1, 1], 9: [1], 8: [1]})

# %% [markdown]
# ## Step 3 - reduce()
#
# <p align="justify">
# <font size="3">
# Here we are going to define a function that does the sum:
# </font>
# </p>

# %%
#Provide here few comment lines that describe your reduce function

def reduce_num_counter_sol(dict) :
    res = []
    #to complete with your code
    for k in dict:
        res.append((k,sum(dict[k])))
                   
    return res

res = reduce_num_counter_sol(shuffle_pairs_sol(map_num_counter_sol(array_numbers)))
print(res)
# Out:
# [(1, 1), (2, 1), (3, 3), (4, 3), (5, 1), (6, 1), (7, 2), (9, 1), (8, 1)]

# %% [markdown]
# # Exercise 3:  Inverted index
#
# <p align="justify">
# <font size="3">
# In this exercise, we want to create an inverted index, an index that associates each word to the list of the file names in which the word occurs in.
# </font>
# </p>
#
# <p align="justify">
# <font size="3">
# We are going to read the file books.json. This file contains some lines. Each line represents a different file containing a book.  We are going to provide you the function for reading this file and the function will so ignore the detail of the representation of each book.
# </font>
# </p>
#
#
#
# ### The function that reads the json file
#
# <p align="justify">
# <font size="3">
# Python provides functions for reading JSON files and producing (dict, list) for what has been read. The function reads the data stored in the book.json file
#
# Moreover the yield() instructions allows to code a generator that produces the data only when the function is called.
# </font>
# </p>

# %%
import json 
def readData(filename):
    with open(filename, mode='r', encoding='utf-8') as file:
        for line in file:
            record = json.loads(line)
            yield(record)
print(list(readData('books.json')))
# Out:
# [['milton-paradise.txt', "[ Paradise Lost by John Milton 1667 ] Book I Of Man ' s first disobedience , and the fruit Of that forbidden tree whose mortal taste Brought death into the World , and all our woe , With loss of Eden , till one greater Man Restore us , and regain the blissful seat , Sing , Heavenly Muse , that , on the secret top Of Oreb , or of Sinai , didst inspire That shepherd who first taught the chosen seed In the beginning how the heavens and earth Rose out of Chaos : or , if Sion hill Delight thee more , and Siloa ' s brook that flowed Fast by the oracle of God , I thence Invoke thy aid to my adventurous song , That with no middle flight intends to soar Above th ' Aonian mount , while it pursues Things unattempted yet in prose or rhyme ."], ['edgeworth-parents.txt', "[ The Parent ' s Assistant , by Maria Edgeworth ] THE ORPHANS . Near the ruins of the castle of Rossmore , in Ireland , is a small cabin , in which there once lived a widow and her four children . As long as she was able to work , she was very industrious , and was accounted the best spinner in the parish ; but she overworked herself at last , and fell ill , so that she could not sit to her wheel as she used to do , and was obliged to give it up to her eldest daughter , Mary ."], ['austen-emma.txt', "[ Emma by Jane Austen 1816 ] VOLUME I CHAPTER I Emma Woodhouse , handsome , clever , and rich , with a comfortable home and happy disposition , seemed to unite some of the best blessings of existence ; and had lived nearly twenty - one years in the world with very little to distress or vex her . She was the youngest of the two daughters of a most affectionate , indulgent father ; and had , in consequence of her sister ' s marriage , been mistress of his house from a very early period . Her mother had died too long ago for her to have more than an indistinct remembrance of her caresses ; and her place had been supplied by an excellent woman as governess , who had fallen little short of a mother in affection ."], ['chesterton-ball.txt', '[ The Ball and The Cross by G . K . Chesterton 1909 ] I . A DISCUSSION SOMEWHAT IN THE AIR The flying ship of Professor Lucifer sang through the skies like a silver arrow ; the bleak white steel of it , gleaming in the bleak blue emptiness of the evening . That it was far above the earth was no expression for it ; to the two men in it , it seemed to be far above the stars . The professor had himself invented the flying machine , and had also invented nearly everything in it .'], ['bible-kjv.txt', '[ The King James Bible ] The Old Testament of the King James Bible The First Book of Moses : Called Genesis 1 : 1 In the beginning God created the heaven and the earth . 1 : 2 And the earth was without form , and void ; and darkness was upon the face of the deep . And the Spirit of God moved upon the face of the waters . 1 : 3 And God said , Let there be light : and there was light . 1 : 4 And God saw the light , that it was good : and God divided the light from the darkness . 1 : 5 And God called the light Day , and the darkness he called Night . And the evening and the morning were the first day .'], ['chesterton-thursday.txt', '[ The Man Who Was Thursday by G . K . Chesterton 1908 ] To Edmund Clerihew Bentley A cloud was on the mind of men , and wailing went the weather , Yea , a sick cloud upon the soul when we were boys together . Science announced nonentity and art admired decay ; The world was old and ended : but you and I were gay ; Round us in antic order their crippled vices came -- Lust that had lost its laughter , fear that had lost its shame . Like the white lock of Whistler , that lit our aimless gloom , Men showed their own white feather as proudly as a plume . Life was a fly that faded , and death a drone that stung ; The world was very old indeed when you and I were young .'], ['blake-poems.txt', '[ Poems by William Blake 1789 ] SONGS OF INNOCENCE AND OF EXPERIENCE and THE BOOK of THEL SONGS OF INNOCENCE INTRO ...

# %% [markdown]
# <p align="justify">
# <font size="3">
#
# You can store the output of the reading in a list where the first element of the list will be the file name and the second element will contain the title and the content of the book.
#
# Now that you have the function that reads the file you can focus on the MapReduce procedure.
#
# The expected output of the MapReduce procedure is a list [] that contains a set of (w, L) elements, where w is a word appearing in at least one text of the given books and L is the list of the names of the files containing w (without repetition).
# Given this book representation describe a possible implementation of the
#
# <ol>
#     <li> map() function that given the text produces a set of key/value pairs</li>
#     <li> shuffle() function that groups the key/value pairs according to a criteria </li>
#     <li> reduce() function that produces the final result</li>
# </ol>
# detailing all the actions that the map() function and a reduce() functions must perform.
# </font>

# %%
# Provide here few comment lines that describe your map-reduce procedure

import re
regex = re.compile('[^a-zA-Z]')
def mapper_inv_index(input):
    res = []
    #to complete with your code
    for line in input:
        file = line[0] #第line 行的名称
        #words = line[1].split
        #res.append([(w,file) for w in words])
        for words in line[1].split(): #第line行的所有内容
            words = regex.sub('',words)
            if len(words) > 0:
                words = words.lower() #大写和小写不区分
                res.append([(w,file) for w in words])
    return res

def shuffler_inv_index(input): 
    #to complete with your code
    res = defaultdict(list)
    for line in input :
        for (k,v) in line :
            res[k].append(v) #字典的用法[(A,[1,2,3,4...]),...]
    
    return res
def reducer_inv_index(dict): 
    res = []
    #to complete with your code
    for key in dict :
        res.append((key,list(set(dict[key]))))
    return res

print(reducer_inv_index(shuffler_inv_index(mapper_inv_index(list(readData('books.json'))))))

# %% [markdown]
# Discuss what can be improved in the algorithm you provided and check which operations can be nice that a framework provides for you.

# %% [markdown]
# # Exercise 4. Matrix Multiplication
#
# <p>
# <font size="3">
# We want to define the MapReduce procedure to obtain the matrix $A \times B$. Here you are not suppose to write code but just to think about the representation of the two matrix and to define the general description of the two procedures.
# </font>
# </p>
#
# <p>
# <font size="3">
# We have as input:
# <ul>
# <li> $A$: an $n \times m$ matrix
# <li> $B$: an $m \times p$ matrix.
# </ul>
# The procedure returns the matrix obtained by multiplying the first and the second matrix.
# The multiplication can only be computed if the number of columns of $A$ equals the number of rows of $B$.
# </font>
#
# </p>
#
#
# <p>
# Consider the following A matrix:
# <p>
# <center>
#   $A= \begin{bmatrix}
#     1 & 2 & 4   \\
#     4 & 5 & 6
# \end{bmatrix}$
# </center>
# </p>
#
# <p>
# Then consider the following B matrix:
# <p>
# <center>
#   $B= \begin{bmatrix}
#     a & b    \\
#     c & d   \\
#     e & f
# \end{bmatrix}$
# </center>
# </p>
#
# <p>
# <font size="3">
# Since we are in a MapReduce context can represent these two matrix as a set of key-value pairs, where the key is the coordinate (row identifier, column identifier) of an element, and the value is the element itself.
#
# This matrix representation is the starting point for defining your matrix representation in the following part of the exercise.
# </font>
# </p>
#
# <p>
# <font size="3">
# For the matrix A: $( (0, 0), 1 ), ( (0, 1), 2 ), ( (0, 2), 4 ), ( (1, 0), 4 ), ( (1, 1), 5 ), ( (1, 2), 6 )$
#
# For the matrix B: $( (0, 0), a ), ( (0, 1), b ), ( (1, 0), c ), ( (1, 1), d ), ( (2, 0), e ), ( (2, 1), f )$
#
# </font>
# </p>
#
#
# <p>
# <font size="3">
# The result of the matrix multiplication will be a matrix $C = A \times B$ is a $n \times p$ matrix, where each element $c_{i, k}$ is computed as
# follows:
# <center>
#   $c_{i, k} = \sum\limits_{j=0}^{m-1} a_{i, j} \cdot b_{j, k} \quad\quad (1)$
# </center>
# </font>
# </p>
#
# <p>
# <center>
#   $C= \begin{bmatrix}
#     1a + 2c + 4e & 1b + 2d + 4f   \\
#     4a + 5c + 6e & 4b + 5d + 6f   \\
# \end{bmatrix}$
# </center>
# </p>
#
#
#
# <p>
# <font size="3">
#
# As you can see, for a given $(i, k)$, the element of $A$ that is in the j-th column is multiplied by the value of $B$ that is in the j-th row, for any column $j$.
#
#
#
#
# For example the element C(0,0) = A(0,0) B(0,0) + A(0,1) B(1,0) + A(0,2) B(2,0) where $j = 0$
# </font>
# </p>
#
# <p>
# <font size="3">
# Therefore, we can change the representation of $A$ and $B$ so that their elements are indexed by using $j$ as the key. The $j$ will be used to correctly group the elements to run the map and reduce functions.
#
# Remember that the element C(0,0) is computed according to $j=0$.
# </font>
# </p>
#
# <p>
# <font size="3">
# More specifically, we can represent the matrix $A$ as follows:
# <center>
#     $(j, (0, i, a_{i, j})) \quad 0 \leq i \leq n-1 \quad 0 \leq j \leq m-1  \quad\quad (2)$
# </center>
# Since we must still be able to identify to which input matrix each value belongs to, we must add a marker in the representation. In this example we choose the value $0$ in the triple $(0, i, a_{i, j})$ meaning that the element $a_{i, j}$ comes from the matrix $A$.
#
# Notice that in this example we can think that $(j, (0, i, a_{i, j}))$ is a key-value pair where the key is $j$ and the value is $(0, i, a_{i, j})$
# </font>
# </p>
#
# <p>
# <font size="3">
# For the matrix A we will then have: $( 0, (0, 0, 1 )), ( 1, (0, 0, 2 )), ( 2, (0, 0, 4 )), ( 0, (0, 1, 4 )), ( 1, (0, 1, 5 ), ( 2, (0, 1, 6 ))$
# </font>
# </p>
#
# <p>
# <font size="3">
# Similarly, we can represent the matrix $B$ as follows:
# <center>
#     $(j, (1, k, b_{j, k})) \quad 0 \leq j \leq m-1 \quad 0 \leq k \leq p-1 \quad\quad (3) $
# </center>
# even in this case the value $1$ in the triple $(1, k, b_{j, k})$ means that the element $b_{j, k}$ comes from the matrix $B$.
# </font>
# </p>
#
# <p>
# <font size="3">
# For the matrix B we will then have: $( 0, (1, 0, a )), ( 0, (1, 1, b )), ( 1, (1, 0, c )), ( 1, (1, 1, d )), ( 2, (1, 0, e ), ( 2, (1, 1, f ))$
# </font>
# </p>
#
# <p>
# <font size="3">
# Now we can group the values obtained above by their key $j$.
#
# We will have:
# <ol>
#     <li> ( 0, (0, 0, 1 )), ( 0, (0, 1, 4 )), ( 0, (1, 0, a )), ( 0, (1, 1, b ))</li>
#     <li> ( 1, (0, 0, 2 )), ( 1, (0, 1, 5 )), ( 1, (1, 0, c )), ( 1, (1, 1, d ))</li>
#     <li> ( 2, (0, 0, 4 )), ( 2, (0, 1, 6 )), ( 2, (1, 0, e )), ( 2, (1, 1, f ))</li>
# </ol>
# </font>
# </p>
#
# <p>
# <font size="3">
# As we have seen each element can be seen as a key-value pair, where the key is the index $j$ and the value is a triple corresponding to the elements of matrix $A$ in the $j-$th column  and the elements of matrix $B$  in the $j-$row, as follows:
# <p>
# <center>
# $(0, i, a_{i, j})\ 0 \leq i \leq n-1 \quad (1, k, b_{j, k})\ 0 \leq k \leq p-1$
# </center>
# </p>
# <p>
# Remember that all triples corresponding to matrix $A$ have 0 as their first value, while those corresponding to matrix $B$ have 1.
# </p>
# <p>
# From Equation (1), you can see that the product $a_{i, j} \cdot b_{j, k}$ contributes to the value $c_{i, k}$, for $0 \leq i \leq n-1$ and $0 \leq k \leq p-1$.
# Therefore, given the triple, we associate each value $a_{i, j} \cdot b_{j, k}$  with the pair $(i, k)$.
# </p>
# <p>
# Each element is a key-value pair, where the key is $(i, k)$ and the value is $a_{i, j} \cdot b_{j, k}$.
# </p>
#
#
# <p>
# <font size="3">
#     We will have:
# <ol>
#     <li> ((0,0), (1a)), ((0,1), (1b)), ((1,0), (4a)), ((1,1), (4b))</li>
#     <li> ((0,0), (2c)), ((0,1), (2d)), ((1,0), (5c)), ((1,1), (5d))</li>
#     <li> ((0,0), (4e)), ((0,1), (6f)), ((1,0), (6e)), ((1,1), (6f))</li>
#
# </ol>
# </font>
# </p>
#
# <p>
# Here we can group the elements, where each element is a pair $((i, k), a_{i, j} \cdot b_{j, k})$, $0 \leq i \leq n-1$ and $0 \leq k \leq p-1$.
# <font size="3">
# <ol>
#     <li> ((0,0), (1a)), ((0,0), (2c)), ((0,0), (4e)) </li>
#     <li> ((0,1), (1b)), ((0,1), (2d)), ((0,1), (6f)) </li>
#     <li> ((1,0), (4a)), ((1,0), (5c)), ((1,0), (6e)) </li>
#     <li> ((1,1), (4b)), ((1,1), (5d)), ((1,1), (6f)) </li>
# </ol>
# </font>
# </p>
#
#
#
#
#
# <p>
# <font size="3">
# From Equation (1), we can see that each $c_{i, k}$ is obtained by summing up the products $a_{i, j} \cdot b_{j, k}$, $0 \leq j \leq m-1$.
# <p>
# Therefore, in order to obtain the matrix $C = A \times B$, the only thing that we need to do is to sum all
# values $a_{i, j} \cdot b_{j, k}$ associated with the same key $(i, k)$.
# </p>
# </font>
# </p>
#
# <p>
# <center>
#   $C= \begin{bmatrix}
#     1a + 2c + 4e & 1b + 2d + 4f   \\
#     4a + 5c + 6e & 4b + 5d + 6f   \\
# \end{bmatrix}$
# </center>
# </p>

# %%
#Provide here a description of a MapReduce procedure implementing the matrix product. 
A = [[0,1,2,4],
    [1,2,3,10],
    [2,12,15,150]]
B = [[0,4,2,2],
    [1,1,3,3],
    [2,23,34,12],
    [1,1,3,3]]
def load_matrix(input):
    res = []
    i = 0
    for line in input:
        j = 0
        for e in line:
            res.append(((i,j),input[i][j]))
            j = j+1
        i = i+1
    return res

print("A = ")
print(load_matrix(A))
print("B = ")
print(load_matrix(B))

def mapper_A(input) :
    res = []
    for (k,v) in input :
        res.append((k[1],(0,k[0],v)))
    return res
def mapper_B(input):
    res = []
    for (k,v) in input :
        res.append((k[0],(1,k[1],v)))
    return res

print("A = ")
print(mapper_A(load_matrix(A)))
print("B = ")
print(mapper_B(load_matrix(B)))

def shuffle_matrix(A,B):
    res_1 = []
    for(j_a,v_a) in A:
        for(j_b,v_b) in B:
            if j_a == j_b :
                res_1.append(((v_a[1],v_b[1]),v_a[2]*v_b[2]))

    res = defaultdict(list)
    for ((a,b),v) in res_1:
        res[(a,b)].append(v)
    return res

print("𝑎𝑖,𝑗*𝑏𝑗,𝑘=")
print(shuffle_matrix(mapper_A(load_matrix(A)),(mapper_B(load_matrix(B)))))

def reducer_matrix(input):
    res = []
    for k in input :
        res.append((k,sum(input[k])))
    return res
print("C=A*B=")
print(reducer_matrix(shuffle_matrix(mapper_A(load_matrix(A)),(mapper_B(load_matrix(B))))))

#TP:bibilioteque de spark sur py pour gerer ce type de calcul
# Out:
# A =
# [((0, 0), 0), ((0, 1), 1), ((0, 2), 2), ((0, 3), 4), ((1, 0), 1), ((1, 1), 2), ((1, 2), 3), ((1, 3), 10), ((2, 0), 2), ((2, 1), 12), ((2, 2), 15), ((2, 3), 150)]
# B =
# [((0, 0), 0), ((0, 1), 4), ((0, 2), 2), ((0, 3), 2), ((1, 0), 1), ((1, 1), 1), ((1, 2), 3), ((1, 3), 3), ((2, 0), 2), ((2, 1), 23), ((2, 2), 34), ((2, 3), 12), ((3, 0), 1), ((3, 1), 1), ((3, 2), 3), ((3, 3), 3)]
# A =
# [(0, (0, 0, 0)), (1, (0, 0, 1)), (2, (0, 0, 2)), (3, (0, 0, 4)), (0, (0, 1, 1)), (1, (0, 1, 2)), (2, (0, 1, 3)), (3, (0, 1, 10)), (0, (0, 2, 2)), (1, (0, 2, 12)), (2, (0, 2, 15)), (3, (0, 2, 150))]
# B =
# [(0, (1, 0, 0)), (0, (1, 1, 4)), (0, (1, 2, 2)), (0, (1, 3, 2)), (1, (1, 0, 1)), (1, (1, 1, 1)), (1, (1, 2, 3)), (1, (1, 3, 3)), (2, (1, 0, 2)), (2, (1, 1, 23)), (2, (1, 2, 34)), (2, (1, 3, 12)), (3, (1, 0, 1)), (3, (1, 1, 1)), (3, (1, 2, 3)), (3, (1, 3, 3))]
# 𝑎𝑖,𝑗*𝑏𝑗,𝑘=
# defaultdict(<class 'list'>, {(0, 0): [0, 1, 4, 4], (0, 1): [0, 1, 46, 4], (0, 2): [0, 3, 68, 12], (0, 3): [0, 3, 24, 12], (1, 0): [0, 2, 6, 10], (1, 1): [4, 2, 69, 10], (1, 2): [2, 6, 102, 30], (1, 3): [2, 6, 36, 30], (2, 0): [0, 12, 30, 150], (2, 1): [8, 12, 345, 150], (2, 2): [4, 36, 510, 450], (2, 3): [4, 36, 180, 450]})
# C=A*B=
# [((0, 0), 9), ((0, 1), 51), ((0, 2), 83), ((0, 3), 39), ((1, 0), 18), ((1, 1), 85), ((1, 2), 140), ((1, 3), 74), ((2, 0), 192), ((2, 1), 515), ((2, 2), 1000), ((2, 3), 670)]
